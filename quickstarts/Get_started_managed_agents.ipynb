# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitd8282-tech/Cricket-Score-Prediction/blob/main/quickstarts/Get_started_managed_agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## preprocess

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.tail()
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1

# %%
df.shape
# Out:
# (100, 4)

# %%
df=df.iloc[:,1:]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
## extract the input and output

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
## train the model

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing    import StandardScaler

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %% [markdown]
# Training

# %%
x_train
# Out:
# array([[ 1.27978296,  0.15985773],
#        [ 0.75544093,  0.35898846],
#        [-0.81758517,  0.11007504],
#        [ 1.10500228, -0.9353613 ],
#        [-0.29324314,  1.13062004],
#        [ 0.49326991, -0.08905569],
#        [-2.39061126,  1.47909882],
#        [ 0.49326991,  0.35898846],
#        [ 0.66805059,  0.43366248],
#        [-0.64280449, -0.23840374],
#        [-0.2058528 ,  0.45855382],
#        [-0.99236585, -0.08905569],
#        [ 0.9302216 , -1.88123227],
#        [ 0.66805059, -0.01438166],
#        [ 0.84283127,  1.27996809],
#        [ 0.66805059, -0.83579593],
#        [ 0.84283127,  1.87736028],
#        [ 0.84283127, -0.28818642],
#        [ 0.75544093,  0.3838798 ],
#        [-0.2058528 ,  1.05594602],
#        [ 0.2310989 , -0.51220849],
#        [-0.55541415,  0.3838798 ],
#        [-1.86626923, -0.36286044],
#        [ 1.97890567,  1.1057287 ],
#        [ 1.10500228, -0.18862105],
#        [ 0.14370856, -0.26329508],
#        [-1.42931754,  0.63279321],
# ...

# %%
x_test
# Out:
# array([[-0.39297827,  0.23572453],
#        [-0.89679657, -1.02708547],
#        [-0.59450559, -0.15714969],
#        [-0.19145095, -0.26939947],
#        [-1.29985121,  2.14397075],
#        [ 1.4207676 ,  0.43216164],
#        [ 0.51389466, -1.64445924],
#        [ 0.413131  , -0.6061488 ],
#        [-0.89679657, -0.07296236],
#        [ 1.92458589,  0.96534809]])

# %% [markdown]
# Model Evaluation

# %%
classifier.predict(x_test)
# Out:
# array([0, 0, 0, 0, 0, 1, 1, 1, 0, 1])

# %%
y_test
# Out:
# 19    0
# 23    0
# 67    0
# 41    0
# 95    0
# 32    1
# 56    0
# 62    0
# 24    0
# 91    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values, clf=classifier, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(classifier,open('model.pkl','wb'))

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 28.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 40.7 MB/s eta 0:00:00
# ...

# %%
import streamlit

print("Streamlit installed successfully!")
# Out:
# Streamlit installed successfully!

# %%
# !streamlit run app.py
# Out:
# Usage: streamlit run [OPTIONS] [TARGET] [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Invalid value: File does not exist: app.py
